# %% [markdown]
# # Information Retreival
#
# Created by : FrancoisHUP
# Last update : 20 dec 2023
#
# We are doing indexation on TREC AP 88-90 documents and querying the system with 150 requests.
# Then we check the MAP score.
#
# 0. Utils
# 1. Config env
# 2. Data loading
# 3. Tokenization
# 4. Indexing
# 5. Search
# 6. Evaluation
#
# It create an index for each tokenisation methode.

# %%
# !python3 -m pip install openai
# Out:
# Collecting openai
#   Using cached openai-1.6.0-py3-none-any.whl (225 kB)
# Collecting typing-extensions<5,>=4.7
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pydantic<3,>=1.9.0
#   Using cached pydantic-2.5.2-py3-none-any.whl (381 kB)
# Requirement already satisfied: tqdm>4 in ./.venv-linux/lib/python3.10/site-packages (from openai) (4.66.1)
# Collecting httpx<1,>=0.23.0
#   Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# Collecting anyio<5,>=3.5.0
#   Using cached anyio-4.2.0-py3-none-any.whl (85 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting idna>=2.8
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv-linux/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.2-py3-none-any.whl (76 kB)
# Collecting certifi
#   Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting pydantic-core==2.14.5
#   Using cached pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Installing collected packages: typing-extensions, sniffio, idna, h11, distro, certifi, annotated-types, pydantic-core, httpcore, anyio, pydantic, httpx, openai
# Successfully installed annotated-types-0.6.0 anyio-4.2.0 certifi-2023.11.17 distro-1.8.0 h11-0.14.0 httpcore-1.0.2 httpx-0.26.0 idna-3.6 openai-1.6.0 pydantic-2.5.2 pydantic-core-2.14.5 sniffio-1.3.0 typing-extensions-4.9.0

# %%
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key= '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' # os.environ.get("OPENAI_API_KEY"),
)

def expand_request() : 
    query = 'diabetes type 2 effect on organ tissues'

    # Define the prompt you want to send
    prompt = '''
        Expand the following search query for a more comprehensive search in a medical database. Original query: 
        'type 2 diabetes'. Include synonyms, related conditions, and treatment options. Avoid overly technical 
        terms and provide the expanded query terms in a list format.
    ''' + query


    completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": "Say this is a test",
            }
        ],
        model="gpt-3.5-turbo",
    )
    
    # Print the response
    print(completion.choices[0].message.content)
    print('prompt : ', prompt)
    
    return completion.choices[0].message.content

# %% [markdown]
# ### Get documents

# %%
import glob
import gzip
import re

doc_pattern = re.compile(r'<DOC>(.*?)</DOC>', re.DOTALL)
docno_pattern = re.compile(r'<DOCNO>\s*(.*?)\s*</DOCNO>')
head_pattern = re.compile(r'<HEAD>\s*(.*?)\s*</HEAD>')
text_pattern = re.compile(r'<TEXT>\s*(.*?)\s*</TEXT>', re.DOTALL)

def get_documents() :
    documents = []
    # Get a list of all .gz files in the "Ap" directory
    file_list = glob.glob('TREC AP 88-90/TREC AP 88-90/collection de documents/AP/*.gz') # start from ../src

    # Loop over the list of files
    for filename in file_list:
        
        # Open the .gz file
        with gzip.open(filename, 'rt', encoding='latin1') as file:  # 'rt' mode for text reading
            # Read the contents of the file
            content = file.read()
            for doc in doc_pattern.finditer(content):
                doc_content = doc.group(1)

                # Extracting individual elements
                doc_id = docno_pattern.search(doc_content).group(1)
                head = head_pattern.search(doc_content)
                text = text_pattern.search(doc_content)
                
                documents.append([doc_id, head.group(1) if head else '',text.group(1) if text else ''])

    return documents

documents = get_documents()
print(documents[0])
# Out:
# ['AP880212-0001', 'Reports Former Saigon Officials Released from Re-education Camp', "More than 150 former officers of the\noverthrown South Vietnamese government have been released from a\nre-education camp after 13 years of detention, the official Vietnam\nNews Agency reported Saturday.\n   The report from Hanoi, monitored in Bangkok, did not give\nspecific figures, but said those freed Friday included an\nex-Cabinet minister, a deputy minister, 10 generals, 115\nfield-grade officers and 25 chaplains.\n   It quoted Col. Luu Van Ham, director of the Nam Ha camp south of\nHanoi, as saying all 700 former South Vietnamese officials who had\nbeen held at the camp now have been released.\n   They were among 1,014 South Vietnamese who were to be released\nfrom re-education camps under an amnesty announced by the Communist\ngovernment to mark Tet, the lunar new year that begins Feb. 17.\n   The Vietnam News Agency report said many foreign journalists and\na delegation from the Australia-Vietnam Friendship Association\nattended the Nam Ha release ceremony.\n   It said Lt. Gen. Nguyen Vinh Nghi, former commander of South\nVietnam's Third Army Corps, and Col. Tran Duc Minh, former director\nof the Army Infantry Officers School, expressed ``gratitude to the\ngovernment for its humane treatment in spite of the fact that most\nof them (detainees) had committed heinous crimes against the\ncountry and people.''\n   The prisoners had been held without formal charges or trial\nsince North Vietnam defeated the U.S.-backed South Vietnamese\ngovernment in April 1975, ending the Vietnam War.\n   Communist authorities had called the prisoners war criminals and\nsaid they had to learn how to become citizens of the new society.\n   Small numbers had been released occasionally without publicity\nbut the government announced last year that 480 political prisoners\nwould be freed to mark National Day on Sept. 2.\n   On Thursday, Vice Minister of Information Phan Quang said 1,014\nwould be released under the Tet amnesty.\n   He reported a total of 150 prisoners would remain in the camps,\nwhich he said once held 100,000.\n   ``Depending on their repentance, they will gradually be released\nwithin a short period of time,'' Quang said.\n   He said many of the former inmates would return to their\nfamilies in Ho Chi Minh City, formerly the South Vietnamese capital\nof Saigon.\n   The amnesties apparently are part of efforts by Communist Party\nchief Nguyen Van Linh to heal internal divisions and improve\nVietnam's image abroad."]

# %% [markdown]
# ### LUCENE

# %%
import lucene
from org.apache.lucene.analysis.standard import StandardAnalyzer
from org.apache.lucene.analysis.en import EnglishAnalyzer
from org.apache.lucene.document import Document, Field, StringField, TextField
from org.apache.lucene.index import IndexWriter, IndexWriterConfig
from org.apache.lucene.index import DirectoryReader
from org.apache.lucene.store import MMapDirectory
from java.nio.file import Paths
from org.apache.lucene.search import IndexSearcher
from org.apache.lucene.queryparser.classic import QueryParser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import lucene
#       2 from org.apache.lucene.analysis.standard import StandardAnalyzer
#       3 from org.apache.lucene.analysis.en import EnglishAnalyzer
#
# ModuleNotFoundError: No module named 'lucene'

# %%
lucene.initVM()

# %%
analyzer = StandardAnalyzer()
# analyzer = EnglishAnalyzer()
index = MMapDirectory(Paths.get("indexBasic"))  # specify a directory path
config = IndexWriterConfig(analyzer)
writer = IndexWriter(index, config)

# %%
for document in documents:
    doc = Document()
    doc.add(StringField("doc_id", document[0], Field.Store.YES))  # Add your custom doc ID
    doc.add(TextField("content", document[1] + document[2], Field.Store.YES))
    writer.addDocument(doc)
writer.close()

# %%
print(documents[1])
# Out:
# ['AP880212-0002', 'Iowa Caucus Results Shake Up New Hampshire Race', "The ripples from the Iowa precinct caucuses are\nspreading to New Hampshire, boosting winners and damaging losers in\nthe final days before the nation's first primary, polls indicate.\n   Vice President George Bush, who was slipping in New Hampshire\neven before his third-place Iowa finish, lost more ground in polls\nthis week. Democratic third-place finisher Michael Dukakis also\nlost support, but not as much.\n   Iowa, meanwhile, has boosted the candidacies of Rep. Richard\nGephardt of Missouri and Sen. Bob Dole of Kansas, the Democratic\nand Republican winners, and has aided Pat Robertson, Iowa's\nsurprise second-place Republican finisher, the polls indicate.\n   As recently as two weeks ago, Bush commanded the New Hampshire\nGOP field. A CBS News-New York Times poll in the last week of\nJanuary had him 22 percentage points over Dole, the same place he'd\nheld in polls since November and earlier.\n   But a crack appeared last week, when an ABC News-Washington Post\npoll found Bush's lead sharply diminished, to 7 percentage points.\nAfter Iowa's vote Monday, ABC found the spread down to 4 percentage\npoints: Bush, 33, Dole, 29.\n   In a poll with an error margin of 6 percentage points, that\namounted to a dead heat. Another survey, done for The Boston Globe\nthis week by pollster Gary Orren, had essentially he same result:\nBush 29, Dole 27. CBS on Thursday had it as Bush 35, Dole 27 _\nstill a big drop for the vice president.\n   ``Dole got a very big kick out of Iowa; more than that, there is\nsome reluctance in the support for Bush,'' Orren said Thursday.\n``He's shown vulnerability, and that's sort of arousing doubts\npeople have about him.''\n   ``The unanswered question is how far Bush will fall,'' Richard\nMorin, polling director for The Washington Post. ``The expectation\nis that he will continue to drop. That's been the clear direction.''\n   If voters were leaving Bush before Iowa, it was not clear where\nthey were going, Morin said. This week the chief gainers turned out\nto be Dole and Robertson, whose support was up to 10 percent in the\nABC and CBS polls, from 6 percent last week and 4 percent two weeks\nago.\n   Rep. Jack Kemp of New York held steady at 13 percent in the ABC\npoll, and fell from 16 percent to 12 percent in the CBS poll.\nAnalysts said he now may be challenged by Robertson for third place\nin New Hampshire.\n   ``Kemp was gaining last week. Iowa ended that,'' said Morin.\n   Iowa's effect on the Democratic race probably is in the battle\nfor second place, not first, pollsters said. Massachusetts Gov.\nDukakis, despite finishing third in Iowa, maintained a strong lead\nin New Hampshire _ but he no longer had the huge 49 percent support\nindicated in an NBC-Wall Street Journal poll in November.\n   Three polls indicated a drop in support for Dukakis, to 36\npercent in the ABC-Post survey this week from 41 percent last week;\nto 35 percent in the Globe's survey, from 38 percent last week; and\nto 38 percent in the CBS poll, from 40 percent in late January.\n   A fourth new poll, however _ done for WBZ-TV in Boston, WRC-TV\nin Washington and the Boston Herald _ said Dukakis' support had\nrisen from 36 percent at the end of January to 44 percent this week.\n   ``It's a big lead for Dukakis no matter whose poll you're\nlooking at _ and a strong one, too,'' said Jeff Alderman, chief of\npolling for ABC News. He said 58 percent of Dukakis' backers told\nABC they supported him strongly.\n   The win in Iowa transformed Gephardt, who had single-digit\nsupport in New Hampshire as recently as last month. The CBS poll\nhad him at 19 percent, up from 7 percent in late January; ABC's\npoll put him this week at 22 percent, up from 13 percent last week.\nThe Globe had him at 18 percent, up from 8, and the WBZ poll had\nhim at 17, up from 8 last month.\n   Poll results were more mixed on Gephardt's chief rival, Sen.\nPaul Simon of Illinois, the ...

# %%
reader = DirectoryReader.open(index)
searcher = IndexSearcher(reader)
query = QueryParser("content", analyzer).parse("Iowa")
hits = searcher.search(query, 1000).scoreDocs

# %%
print(f"Found {len(hits)} hits.")
for hit in hits:
    doc = searcher.doc(hit.doc)
    custom_doc_id = doc.get("doc_id")  # Retrieve your custom doc ID
    print(f"Found (Custom Doc ID: {custom_doc_id})") #:", doc.get("content"))
# Out:
# Found 1000 hits.
# Found (Custom Doc ID: AP900806-0196)
# Found (Custom Doc ID: AP901203-0052)
# Found (Custom Doc ID: AP890601-0207)
# Found (Custom Doc ID: AP900622-0251)
# Found (Custom Doc ID: AP880222-0087)
# Found (Custom Doc ID: AP890420-0052)
# Found (Custom Doc ID: AP880625-0198)
# Found (Custom Doc ID: AP900111-0123)
# Found (Custom Doc ID: AP880309-0214)
# Found (Custom Doc ID: AP900822-0018)
# Found (Custom Doc ID: AP880404-0143)
# Found (Custom Doc ID: AP890614-0245)
# Found (Custom Doc ID: AP890619-0255)
# Found (Custom Doc ID: AP890618-0051)
# Found (Custom Doc ID: AP900616-0098)
# Found (Custom Doc ID: AP901014-0065)
# Found (Custom Doc ID: AP890725-0104)
# Found (Custom Doc ID: AP900611-0015)
# Found (Custom Doc ID: AP880212-0002)
# Found (Custom Doc ID: AP880326-0048)
# Found (Custom Doc ID: AP880621-0116)
# Found (Custom Doc ID: AP890530-0085)
# Found (Custom Doc ID: AP901225-0043)
# Found (Custom Doc ID: AP880721-0015)
# Found (Custom Doc ID: AP880413-0273)
# Found (Custom Doc ID: AP880412-0243)
# Found (Custom Doc ID: AP890611-0055)
# Found (Custom Doc ID: AP890512-0242)
# Found (Custom Doc ID: AP880729-0063)
# Found (Custom Doc ID: AP880825-0053)
# Found (Custom Doc ID: AP881004-0025)
# Found (Custom Doc ID: AP880622-0091)
# Found (Custom Doc ID: AP890113-0229)
# Found (Custom Doc ID: AP890118-0299)
# Found (Custom Doc ID: AP890126-0009)
# Found (Custom Doc ID: AP880802-0233)
# Found (Custom Doc ID: AP890421-0065)
# Found (Custom Doc ID: AP891202-0005)
# Found (Custom Doc ID: AP880216-0023)
# Found (Custom Doc ID: AP900709-0022)
# Found (Custom Doc ID: AP890618-0076)
# Found (Custom Doc ID: AP900604-0018)
# Found (Custom Doc ID: AP900412-0172)
# Found (Custom Doc ID: AP901021-0039)
# Found (Custom Doc ID: AP890419-0199)
# Found (Custom Doc ID: AP890612-0030)
# Found (Custom Doc ID: AP890424-0233)
# Found (Custom Doc ID: AP890421-0013)
# Found (Custom Doc ID: AP900525-0146)
# Found (Custom Doc ID: AP880524-0158)
# Found (Custom Doc ID: AP900618-0170)
# Found (Custom Doc ID: AP880824-0305)
# Found (Custom Doc ID: AP881119-0073)
# Found (Custom Doc ID: AP880413-0266)
# Found (Custom Doc ID: AP880624-0106)
# Found (Custom Doc ID: AP890919-0169)
# Found (Custom Doc ID: AP900118-0105)
# Found (Custom Doc ID: AP880514-0157)
# Found (Custom Doc ID: AP881120-0017)
# Found (Custom Doc ID: AP900118-0067)
# Found (Custom Doc ID: AP880515-0047)
# Found (Custom Doc ID: AP890906-0215)
# Found (Custom Doc ID: AP891224-0031)
# Found (Custom Doc ID: AP901022-0009)
# Found (Custom Doc ID: AP880216-0085)
# Found (Custom Doc ID: AP890424-0060)
# Found (Custom Doc ID: AP900906-0026)
# Found (Custom Doc ID: AP891025-0135)
# Found (Custom Doc ID: AP890909-0036)
# Found (Custom Doc ID: AP881206-0239)
# Found (Custom Doc ID: AP900727-0142)
# Found (Custom Doc ID: AP890504-0123)
# Found (Custom Doc ID: AP900118-0206)
# Found (Custom Doc ID: AP890421-0062)
# Found (Custom Doc ID: AP900518-0010)
# Found (Custom Doc ID: AP891118-0129)
# Found (Custom Doc ID: AP880707-0170)
# Found (Custom Doc ID: AP880820-0089)
# Found (Custom Doc ID: AP890506-0100)
# Found (Custom Doc ID: AP900420-0081)
# Found (Custom Doc ID: AP901026-0082)
# Found (Custom Doc ID: AP901205-0275)
# Found (Custom Doc ID: AP900825-0111)
# Found (Custom Doc ID: AP890807-0109)
# Found (Custom Doc ID: AP901026-0112)
# Found (Custom Doc ID: AP880301-0157)
# Found (Custom Doc ID: AP891208-0049)
# Found (Custom Doc ID: AP900209-0299)
# Found (Custom Doc ID: AP881117-0216)
# Found (Custom Doc ID: AP890913-0056)
# Found (Custom Doc ID: AP901222-0005)
# Found (Custom Doc ID: AP890503-0097)
# Found (Custom Doc ID: AP880416-0004)
# Found (Custom Doc ID: AP890615-0124)
# Found (Custom Doc ID: AP900924-0205)
# Found (Custom Doc ID: AP880216-0015)
# Found (Custom Doc ID: AP880826-0268)
# Found (Custom Doc ID: AP890509-0172)
# Found (Custom Doc ID: AP880713-0302)
# Found (Custom Doc ID: AP890808-0012)
# Found (Custom Doc ID: AP890912-0175)
# Found (Custom Doc ID: AP891017-0154)
# Found (Custom Doc ID: AP900718-0180)
# Found (Custom Doc ID: AP900517-0229)
# Found (Custom Doc ID: AP891211-0083)
# Found (Custom Doc ID: AP900220-0004)
# Found (Custom Doc ID: AP900414-0070)
# Found (Custom Doc ID: AP880824-0060)
# Found (Custom Doc ID: AP880810-0194)
# Found (Custom Doc ID: AP900122-0176)
# Found (Custom Doc ID: AP880804-0098)
# Found (Custom Doc ID: AP881108-0104)
# Found (Custom Doc ID: AP891207-0093)
# Found (Custom Doc ID: AP900919-0084)
# Found (Custom Doc ID: AP880216-0075)
# Found (Custom Doc ID: AP880801-0002)
# Found (Custom Doc ID: AP890822-0045)
# Found (Custom Doc ID: AP891017-0085)
# Found (Custom Doc ID: AP891028-0065)
# Found (Custom Doc ID: AP900308-0105)
# Found (Custom Doc ID: AP901010-0096)
# Found (Custom Doc ID: AP890421-0149)
# Found (Custom Doc ID: AP890821-0128)
# Found (Custom Doc ID: AP890919-0025)
# Found (Custom Doc ID: AP891205-0029)
# Found (Custom Doc ID: AP900118-0165)
# Found (Custom Doc ID: AP900413-0028)
# Found (Custom Doc ID: AP901203-0061)
# Found (Custom Doc ID: AP890816-0041)
# Found (Custom Doc ID: AP890606-0102)
# Found (Custom Doc ID: AP900118-0020)
# Found (Custom Doc ID: AP900525-0032)
# Found (Custom Doc ID: AP890816-0202)
# Found (Custom Doc ID: AP890819-0071)
# Found (Custom Doc ID: AP900525-0109)
# Found (Custom Doc ID: AP890807-0090)
# Found (Custom Doc ID: AP890419-0121)
# Found (Custom Doc ID: AP891211-0062)
# Found (Custom Doc ID: AP890425-0013)
# Found (Custom Doc ID: AP880516-0088)
# Found (Custom Doc ID: AP890219-0097)
# Found (Custom Doc ID: AP900508-0274)
# Found (Custom Doc ID: AP890806-0023)
# Found (Custom Doc ID: AP880526-0203)
# Found (Custom Doc ID: AP900127-0120)
# Found (Custom Doc ID: AP900616-0130)
# Found (Custom Doc ID: AP880525-0118)
# Found (Custom Doc ID: AP890424-0081)
# Found (Custom Doc ID: AP890602-0277)
# Found (Custom Doc ID: AP890607-0069)
# Found (Custom Doc ID: AP900115-0133)
# Found (Custom Doc ID: AP900117-0139)
# Found (Custom Doc ID: AP900326-0111)
# Found (Custom Doc ID: AP900618-0243)
# Found (Custom Doc ID: AP890703-0209)
# Found (Custom Doc ID: AP890519-0142)
# Found (Custom Doc ID: AP890531-0299)
# Found (Custom Doc ID: AP900524-0175)
# Found (Custom Doc ID: AP900524-0174)
# Found (Custom Doc ID: AP890810-0065)
# Found (Custom Doc ID: AP890301-0285)
# Found (Custom Doc ID: AP890924-0035)
# Found (Custom Doc ID: AP881129-0182)
# Found (Custom Doc ID: AP890420-0043)
# Found (Custom Doc ID: AP890511-0186)
# Found (Custom Doc ID: AP900812-0061)
# Found (Custom Doc ID: AP901005-0112)
# Found (Custom Doc ID: AP890420-0176)
# Found (Custom Doc ID: AP890602-0028)
# Found (Custom Doc ID: AP890622-0307)
# Found (Custom Doc ID: AP890607-0119)
# Found (Custom Doc ID: AP891005-0059)
# Found (Custom Doc ID: AP890430-0078)
# Found (Custom Doc ID: AP900726-0164)
# Found (Custom Doc ID: AP880212-0007)
# Found (Custom Doc ID: AP890916-0129)
# Found (Custom Doc ID: AP880527-0121)
# Found (Custom Doc ID: AP890421-0100)
# Found (Custom Doc ID: AP890420-0087)
# Found (Custom Doc ID: AP890720-0188)
# Found (Custom Doc ID: AP880217-0086)
# Found (Custom Doc ID: AP890614-0148)
# Found (Custom Doc ID: AP891003-0031)
# Found (Custom Doc ID: AP880708-0197)
# Found (Custom Doc ID: AP890428-0032)
# Found (Custom Doc ID: AP890513-0013)
# Found (Custom Doc ID: AP891217-0002)
# Found (Custom Doc ID: AP890803-0170)
# Found (Custom Doc ID: AP890908-0048)
# Found (Custom Doc ID: AP890227-0051)
# Found (Custom Doc ID: AP880217-0038)
# Found (Custom Doc ID: AP890907-0166)
# Found (Custom Doc ID: AP890606-0023)
# Found (Custom Doc ID: AP880522-0025)
# Found (Custom Doc ID: AP891204-0107)
# Found (Custom Doc ID: AP890420-0089)
# Found (Custom Doc ID: AP890120-0128)
# Found (Custom Doc ID: AP890422-0015)
# Found (Custom Doc ID: AP900526-0107)
# Found (Custom Doc ID: AP900906-0165)
# Found (Custom Doc ID: AP901203-0132)
# Found (Custom Doc ID: AP880217-0169)
# Found (Custom Doc ID: AP880325-0286)
# Found (Custom Doc ID: AP890311-0042)
# Found (Custom Doc ID: AP880906-0132)
# Found (Custom Doc ID: AP890602-0158)
# Found (Custom Doc ID: AP890603-0142)
# Found (Custom Doc ID: AP900315-0044)
# Found (Custom Doc ID: AP900623-0108)
# Found (Custom Doc ID: AP881108-0009)
# Found (Custom Doc ID: AP880622-0041)
# Found (Custom Doc ID: AP900602-0110)
# Found (Custom Doc ID: AP900628-0158)
# Found (Custom Doc ID: AP881205-0267)
# Found (Custom Doc ID: AP880623-0068)
# Found (Custom Doc ID: AP880705-0083)
# Found (Custom Doc ID: AP891115-0185)
# Found (Custom Doc ID: AP900630-0125)
# Found (Custom Doc ID: AP880508-0090)
# Found (Custom Doc ID: AP880912-0237)
# Found (Custom Doc ID: AP881230-0174)
# Found (Custom Doc ID: AP880217-0013)
# Found (Custom Doc ID: AP880521-0009)
# Found (Custom Doc ID: AP890830-0148)
# Found (Custom Doc ID: AP880527-0122)
# Found (Custom Doc ID: AP880223-0201)
# Found (Custom Doc ID: AP900314-0040)
# Found (Custom Doc ID: AP890815-0049)
# Found (Custom Doc ID: AP891108-0213)
# Found (Custom Doc ID: AP890424-0026)
# Found (Custom Doc ID: AP880616-0245)
# Found (Custom Doc ID: AP890722-0137)
# Found (Custom Doc ID: AP890502-0099)
# Found (Custom Doc ID: AP880217-0008)
# Found (Custom Doc ID: AP880324-0219)
# Found (Custom Doc ID: AP890816-0203)
# Found (Custom Doc ID: AP891004-0001)
# Found (Custom Doc ID: AP900116-0172)
# Found (Custom Doc ID: AP900505-0008)
# Found (Custom Doc ID: AP901109-0016)
# Found (Custom Doc ID: AP880429-0137)
# Found (Custom Doc ID: AP890930-0131)
# Found (Custom Doc ID: AP900111-0159)
# Found (Custom Doc ID: AP900720-0155)
# Found (Custom Doc ID: AP901215-0121)
# Found (Custom Doc ID: AP890525-0194)
# Found (Custom Doc ID: AP880928-0048)
# Found (Custom Doc ID: AP890706-0122)
# Found (Custom Doc ID: AP891111-0054)
# Found (Custom Doc ID: AP900410-0127)
# Found (Custom Doc ID: AP890423-0090)
# Found (Custom Doc ID: AP890428-0058)
# Found (Custom Doc ID: AP880216-0181)
# Found (Custom Doc ID: AP880315-0208)
# Found (Custom Doc ID: AP880328-0022)
# Found (Custom Doc ID: AP880715-0225)
# Found (Custom Doc ID: AP890830-0024)
# Found (Custom Doc ID: AP891030-0060)
# Found (Custom Doc ID: AP891110-0152)
# Found (Custom Doc ID: AP900629-0103)
# Found (Custom Doc ID: AP901126-0128)
# Found (Custom Doc ID: AP890215-0215)
# Found (Custom Doc ID: AP890817-0064)
# Found (Custom Doc ID: AP890829-0091)
# Found (Custom Doc ID: AP881119-0008)
# Found (Custom Doc ID: AP890426-0095)
# Found (Custom Doc ID: AP900314-0138)
# Found (Custom Doc ID: AP880330-0036)
# Found (Custom Doc ID: AP880802-0238)
# Found (Custom Doc ID: AP880820-0059)
# Found (Custom Doc ID: AP890503-0056)
# Found (Custom Doc ID: AP890511-0134)
# Found (Custom Doc ID: AP891113-0136)
# Found (Custom Doc ID: AP891205-0097)
# Found (Custom Doc ID: AP891217-0032)
# Found (Custom Doc ID: AP900602-0169)
# Found (Custom Doc ID: AP900615-0141)
# Found (Custom Doc ID: AP900619-0238)
# Found (Custom Doc ID: AP900719-0045)
# Found (Custom Doc ID: AP901107-0129)
# Found (Custom Doc ID: AP880216-0005)
# Found (Custom Doc ID: AP880404-0097)
# Found (Custom Doc ID: AP890907-0196)
# Found (Custom Doc ID: AP881012-0210)
# Found (Custom Doc ID: AP891011-0038)
# Found (Custom Doc ID: AP890530-0161)
# Found (Custom Doc ID: AP891110-0075)
# Found (Custom Doc ID: AP891116-0155)
# Found (Custom Doc ID: AP900721-0095)
# Found (Custom Doc ID: AP880308-0242)
# Found (Custom Doc ID: AP880806-0046)
# Found (Custom Doc ID: AP880823-0180)
# Found (Custom Doc ID: AP890907-0202)
# Found (Custom Doc ID: AP890228-0112)
# Found (Custom Doc ID: AP900712-0135)
# Found (Custom Doc ID: AP890125-0244)
# Found (Custom Doc ID: AP880617-0189)
# Found (Custom Doc ID: AP891223-0124)
# Found (Custom Doc ID: AP880304-0024)
# Found (Custom Doc ID: AP880819-0247)
# Found (Custom Doc ID: AP891109-0107)
# Found (Custom Doc ID: AP891010-0117)
# Found (Custom Doc ID: AP881107-0094)
# Found (Custom Doc ID: AP890503-0158)
# Found (Custom Doc ID: AP890508-0120)
# Found (Custom Doc ID: AP901229-0085)
# Found (Custom Doc ID: AP880217-0067)
# Found (Custom Doc ID: AP880228-0032)
# Found (Custom Doc ID: AP900526-0065)
# Found (Custom Doc ID: AP880715-0215)
# Found (Custom Doc ID: AP890822-0027)
# Found (Custom Doc ID: AP890907-0182)
# Found (Custom Doc ID: AP890907-0184)
# Found (Custom Doc ID: AP890303-0069)
# Found (Custom Doc ID: AP900619-0133)
# Found (Custom Doc ID: AP880823-0006)
# Found (Custom Doc ID: AP891108-0105)
# Found (Custom Doc ID: AP880708-0117)
# Found (Custom Doc ID: AP891205-0025)
# Found (Custom Doc ID: AP900606-0223)
# Found (Custom Doc ID: AP890818-0013)
# Found (Custom Doc ID: AP881005-0211)
# Found (Custom Doc ID: AP891025-0115)
# Found (Custom Doc ID: AP881103-0119)
# Found (Custom Doc ID: AP890502-0149)
# Found (Custom Doc ID: AP900104-0181)
# Found (Custom Doc ID: AP900723-0011)
# Found (Custom Doc ID: AP880827-0024)
# Found (Custom Doc ID: AP890131-0183)
# Found (Custom Doc ID: AP891002-0165)
# Found (Custom Doc ID: AP890417-0247)
# Found (Custom Doc ID: AP880219-0178)
# Found (Custom Doc ID: AP890224-0132)
# Found (Custom Doc ID: AP880904-0059)
# Found (Custom Doc ID: AP890925-0032)
# Found (Custom Doc ID: AP880620-0029)
# Found (Custom Doc ID: AP891227-0074)
# Found (Custom Doc ID: AP900206-0032)
# Found (Custom Doc ID: AP900326-0184)
# Found (Custom Doc ID: AP901113-0099)
# Found (Custom Doc ID: AP880217-0037)
# Found (Custom Doc ID: AP880217-0042)
# Found (Custom Doc ID: AP880327-0075)
# Found (Custom Doc ID: AP890729-0146)
# Found (Custom Doc ID: AP890420-0188)
# Found (Custom Doc ID: AP890421-0099)
# Found (Custom Doc ID: AP890522-0232)
# Found (Custom Doc ID: AP890420-0004)
# Found (Custom Doc ID: AP880215-0142)
# Found (Custom Doc ID: AP880815-0044)
# Found (Custom Doc ID: AP890716-0026)
# Found (Custom Doc ID: AP890920-0081)
# Found (Custom Doc ID: AP891019-0032)
# Found (Custom Doc ID: AP880328-0125)
# Found (Custom Doc ID: AP890908-0068)
# Found (Custom Doc ID: AP891213-0174)
# Found (Custom Doc ID: AP880212-0054)
# Found (Custom Doc ID: AP880329-0254)
# Found (Custom Doc ID: AP880517-0187)
# Found (Custom Doc ID: AP880821-0033)
# Found (Custom Doc ID: AP890316-0011)
# Found (Custom Doc ID: AP891012-0147)
# Found (Custom Doc ID: AP901102-0114)
# Found (Custom Doc ID: AP890909-0144)
# Found (Custom Doc ID: AP881014-0189)
# Found (Custom Doc ID: AP890710-0064)
# Found (Custom Doc ID: AP891213-0146)
# Found (Custom Doc ID: AP900519-0113)
# Found (Custom Doc ID: AP900817-0127)
# Found (Custom Doc ID: AP901203-0136)
# Found (Custom Doc ID: AP880215-0127)
# Found (Custom Doc ID: AP880425-0199)
# Found (Custom Doc ID: AP880728-0041)
# Found (Custom Doc ID: AP880822-0166)
# Found (Custom Doc ID: AP890731-0017)
# Found (Custom Doc ID: AP890215-0139)
# Found (Custom Doc ID: AP881025-0161)
# Found (Custom Doc ID: AP890602-0135)
# Found (Custom Doc ID: AP890613-0103)
# Found (Custom Doc ID: AP891011-0075)
# Found (Custom Doc ID: AP880701-0073)
# Found (Custom Doc ID: AP890421-0186)
# Found (Custom Doc ID: AP890520-0105)
# Found (Custom Doc ID: AP890530-0170)
# Found (Custom Doc ID: AP890531-0029)
# Found (Custom Doc ID: AP900308-0050)
# Found (Custom Doc ID: AP890419-0194)
# Found (Custom Doc ID: AP880213-0200)
# Found (Custom Doc ID: AP880215-0002)
# Found (Custom Doc ID: AP880430-0068)
# Found (Custom Doc ID: AP880218-0099)
# Found (Custom Doc ID: AP890211-0142)
# Found (Custom Doc ID: AP881103-0242)
# Found (Custom Doc ID: AP900319-0002)
# Found (Custom Doc ID: AP880422-0020)
# Found (Custom Doc ID: AP881220-0047)
# Found (Custom Doc ID: AP880618-0031)
# Found (Custom Doc ID: AP890511-0221)
# Found (Custom Doc ID: AP891209-0019)
# Found (Custom Doc ID: AP900307-0001)
# Found (Custom Doc ID: AP881108-0222)
# Found (Custom Doc ID: AP880217-0111)
# Found (Custom Doc ID: AP881003-0199)
# Found (Custom Doc ID: AP890608-0291)
# Found (Custom Doc ID: AP891109-0183)
# Found (Custom Doc ID: AP880620-0167)
# Found (Custom Doc ID: AP880629-0258)
# Found (Custom Doc ID: AP900313-0021)
# Found (Custom Doc ID: AP900313-0143)
# Found (Custom Doc ID: AP900628-0127)
# Found (Custom Doc ID: AP901217-0110)
# Found (Custom Doc ID: AP890721-0053)
# Found (Custom Doc ID: AP890525-0227)
# Found (Custom Doc ID: AP880728-0152)
# Found (Custom Doc ID: AP890726-0167)
# Found (Custom Doc ID: AP890820-0071)
# Found (Custom Doc ID: AP891017-0036)
# Found (Custom Doc ID: AP891101-0137)
# Found (Custom Doc ID: AP880708-0243)
# Found (Custom Doc ID: AP900207-0136)
# Found (Custom Doc ID: AP900525-0181)
# Found (Custom Doc ID: AP890729-0065)
# Found (Custom Doc ID: AP880212-0029)
# Found (Custom Doc ID: AP880218-0039)
# Found (Custom Doc ID: AP890728-0241)
# Found (Custom Doc ID: AP890822-0013)
# Found (Custom Doc ID: AP890909-0015)
# Found (Custom Doc ID: AP890909-0077)
# Found (Custom Doc ID: AP890630-0049)
# Found (Custom Doc ID: AP890720-0186)
# Found (Custom Doc ID: AP891027-0137)
# Found (Custom Doc ID: AP881121-0024)
# Found (Custom Doc ID: AP890422-0035)
# Found (Custom Doc ID: AP891221-0136)
# Found (Custom Doc ID: AP900113-0127)
# Found (Custom Doc ID: AP900423-0060)
# Found (Custom Doc ID: AP901016-0024)
# Found (Custom Doc ID: AP880215-0179)
# Found (Custom Doc ID: AP880225-0162)
# Found (Custom Doc ID: AP880420-0174)
# Found (Custom Doc ID: AP890425-0075)
# Found (Custom Doc ID: AP890526-0022)
# Found (Custom Doc ID: AP891113-0013)
# Found (Custom Doc ID: AP890719-0184)
# Found (Custom Doc ID: AP890424-0202)
# Found (Custom Doc ID: AP900525-0123)
# Found (Custom Doc ID: AP901203-0274)
# Found (Custom Doc ID: AP890904-0132)
# Found (Custom Doc ID: AP890315-0020)
# Found (Custom Doc ID: AP881003-0349)
# Found (Custom Doc ID: AP890416-0029)
# Found (Custom Doc ID: AP890427-0078)
# Found (Custom Doc ID: AP900614-0165)
# Found (Custom Doc ID: AP901026-0084)
# Found (Custom Doc ID: AP880216-0178)
# Found (Custom Doc ID: AP890419-0135)
# Found (Custom Doc ID: AP880217-0035)
# Found (Custom Doc ID: AP880214-0062)
# Found (Custom Doc ID: AP880304-0245)
# Found (Custom Doc ID: AP880519-0001)
# Found (Custom Doc ID: AP890726-0025)
# Found (Custom Doc ID: AP890824-0237)
# Found (Custom Doc ID: AP880910-0120)
# Found (Custom Doc ID: AP890705-0082)
# Found (Custom Doc ID: AP890720-0019)
# Found (Custom Doc ID: AP890720-0202)
# Found (Custom Doc ID: AP891107-0177)
# Found (Custom Doc ID: AP890505-0196)
# Found (Custom Doc ID: AP891229-0021)
# Found (Custom Doc ID: AP900405-0045)
# Found (Custom Doc ID: AP900508-0113)
# Found (Custom Doc ID: AP900514-0194)
# Found (Custom Doc ID: AP900723-0176)
# Found (Custom Doc ID: AP880212-0011)
# Found (Custom Doc ID: AP880722-0130)
# Found (Custom Doc ID: AP890808-0176)
# Found (Custom Doc ID: AP890904-0118)
# Found (Custom Doc ID: AP890215-0216)
# Found (Custom Doc ID: AP881114-0225)
# Found (Custom Doc ID: AP900104-0129)
# Found (Custom Doc ID: AP900326-0012)
# Found (Custom Doc ID: AP900728-0112)
# Found (Custom Doc ID: AP901103-0004)
# Found (Custom Doc ID: AP901229-0025)
# Found (Custom Doc ID: AP880212-0005)
# Found (Custom Doc ID: AP880225-0116)
# Found (Custom Doc ID: AP880720-0001)
# Found (Custom Doc ID: AP880822-0043)
# Found (Custom Doc ID: AP890822-0133)
# Found (Custom Doc ID: AP890301-0272)
# Found (Custom Doc ID: AP890721-0049)
# Found (Custom Doc ID: AP891017-0175)
# Found (Custom Doc ID: AP891109-0035)
# Found (Custom Doc ID: AP881105-0080)
# Found (Custom Doc ID: AP881117-0019)
# Found (Custom Doc ID: AP890526-0179)
# Found (Custom Doc ID: AP891226-0179)
# Found (Custom Doc ID: AP900108-0057)
# Found (Custom Doc ID: AP900323-0060)
# Found (Custom Doc ID: AP900510-0037)
# Found (Custom Doc ID: AP900516-0010)
# Found (Custom Doc ID: AP890726-0128)
# Found (Custom Doc ID: AP890422-0042)
# Found (Custom Doc ID: AP901106-0186)
# Found (Custom Doc ID: AP880215-0045)
# Found (Custom Doc ID: AP880216-0186)
# Found (Custom Doc ID: AP880217-0088)
# Found (Custom Doc ID: AP880221-0027)
# Found (Custom Doc ID: AP880711-0037)
# Found (Custom Doc ID: AP890917-0071)
# Found (Custom Doc ID: AP890603-0020)
# Found (Custom Doc ID: AP891211-0283)
# Found (Custom Doc ID: AP900121-0055)
# Found (Custom Doc ID: AP900605-0066)
# Found (Custom Doc ID: AP900617-0067)
# Found (Custom Doc ID: AP880214-0075)
# Found (Custom Doc ID: AP880222-0104)
# Found (Custom Doc ID: AP880217-0135)
# Found (Custom Doc ID: AP900421-0042)
# Found (Custom Doc ID: AP900422-0089)
# Found (Custom Doc ID: AP890727-0003)
# Found (Custom Doc ID: AP880217-0065)
# Found (Custom Doc ID: AP890725-0079)
# Found (Custom Doc ID: AP900710-0184)
# Found (Custom Doc ID: AP900713-0197)
# Found (Custom Doc ID: AP880429-0140)
# Found (Custom Doc ID: AP890911-0099)
# Found (Custom Doc ID: AP890224-0187)
# Found (Custom Doc ID: AP881021-0161)
# Found (Custom Doc ID: AP891028-0165)
# Found (Custom Doc ID: AP891031-0045)
# Found (Custom Doc ID: AP880624-0084)
# Found (Custom Doc ID: AP891122-0076)
# Found (Custom Doc ID: AP900318-0056)
# Found (Custom Doc ID: AP900410-0064)
# Found (Custom Doc ID: AP900416-0169)
# Found (Custom Doc ID: AP900608-0113)
# Found (Custom Doc ID: AP901101-0223)
# Found (Custom Doc ID: AP890421-0051)
# Found (Custom Doc ID: AP880217-0020)
# Found (Custom Doc ID: AP890908-0061)
# Found (Custom Doc ID: AP890320-0035)
# Found (Custom Doc ID: AP880629-0107)
# Found (Custom Doc ID: AP890421-0135)
# Found (Custom Doc ID: AP890422-0130)
# Found (Custom Doc ID: AP891214-0024)
# Found (Custom Doc ID: AP900716-0002)
# Found (Custom Doc ID: AP900809-0117)
# Found (Custom Doc ID: AP890908-0058)
# Found (Custom Doc ID: AP880222-0098)
# Found (Custom Doc ID: AP880223-0133)
# Found (Custom Doc ID: AP880224-0176)
# Found (Custom Doc ID: AP880318-0168)
# Found (Custom Doc ID: AP880328-0164)
# Found (Custom Doc ID: AP880411-0153)
# Found (Custom Doc ID: AP890908-0169)
# Found (Custom Doc ID: AP890916-0026)
# Found (Custom Doc ID: AP880902-0256)
# Found (Custom Doc ID: AP881002-0096)
# Found (Custom Doc ID: AP890602-0081)
# Found (Custom Doc ID: AP881227-0131)
# Found (Custom Doc ID: AP890927-0127)
# Found (Custom Doc ID: AP891011-0111)
# Found (Custom Doc ID: AP891108-0282)
# Found (Custom Doc ID: AP880624-0240)
# Found (Custom Doc ID: AP880710-0059)
# Found (Custom Doc ID: AP890530-0043)
# Found (Custom Doc ID: AP891117-0130)
# Found (Custom Doc ID: AP891224-0027)
# Found (Custom Doc ID: AP880626-0092)
# Found (Custom Doc ID: AP891211-0143)
# Found (Custom Doc ID: AP890722-0040)
# Found (Custom Doc ID: AP900423-0116)
# Found (Custom Doc ID: AP901010-0202)
# Found (Custom Doc ID: AP880315-0010)
# Found (Custom Doc ID: AP880723-0111)
# Found (Custom Doc ID: AP880725-0247)
# Found (Custom Doc ID: AP890824-0041)
# Found (Custom Doc ID: AP880709-0153)
# Found (Custom Doc ID: AP891116-0098)
# Found (Custom Doc ID: AP900524-0164)
# Found (Custom Doc ID: AP880216-0183)
# Found (Custom Doc ID: AP880407-0177)
# Found (Custom Doc ID: AP880407-0193)
# Found (Custom Doc ID: AP880505-0240)
# Found (Custom Doc ID: AP880726-0136)
# Found (Custom Doc ID: AP890819-0027)
# Found (Custom Doc ID: AP890822-0037)
# Found (Custom Doc ID: AP890301-0005)
# Found (Custom Doc ID: AP890309-0058)
# Found (Custom Doc ID: AP890620-0065)
# Found (Custom Doc ID: AP890718-0170)
# Found (Custom Doc ID: AP891001-0070)
# Found (Custom Doc ID: AP891029-0050)
# Found (Custom Doc ID: AP880625-0155)
# Found (Custom Doc ID: AP890417-0012)
# Found (Custom Doc ID: AP891215-0186)
# Found (Custom Doc ID: AP900321-0083)
# Found (Custom Doc ID: AP900413-0040)
# Found (Custom Doc ID: AP900504-0149)
# Found (Custom Doc ID: AP900605-0149)
# Found (Custom Doc ID: AP900606-0163)
# Found (Custom Doc ID: AP900730-0106)
# Found (Custom Doc ID: AP901121-0150)
# Found (Custom Doc ID: AP880302-0011)
# Found (Custom Doc ID: AP880728-0234)
# Found (Custom Doc ID: AP890906-0001)
# Found (Custom Doc ID: AP890314-0126)
# Found (Custom Doc ID: AP890420-0090)
# Found (Custom Doc ID: AP900308-0155)
# Found (Custom Doc ID: AP900309-0058)
# Found (Custom Doc ID: AP900417-0005)
# Found (Custom Doc ID: AP900526-0154)
# Found (Custom Doc ID: AP890819-0054)
# Found (Custom Doc ID: AP900531-0073)
# Found (Custom Doc ID: AP881013-0077)
# Found (Custom Doc ID: AP880217-0043)
# Found (Custom Doc ID: AP880217-0179)
# Found (Custom Doc ID: AP880217-0201)
# Found (Custom Doc ID: AP880730-0082)
# Found (Custom Doc ID: AP880808-0134)
# Found (Custom Doc ID: AP880822-0111)
# Found (Custom Doc ID: AP880822-0153)
# Found (Custom Doc ID: AP880902-0169)
# Found (Custom Doc ID: AP890727-0210)
# Found (Custom Doc ID: AP890728-0242)
# Found (Custom Doc ID: AP890908-0032)
# Found (Custom Doc ID: AP890918-0077)
# Found (Custom Doc ID: AP890722-0025)
# Found (Custom Doc ID: AP881118-0160)
# Found (Custom Doc ID: AP880523-0057)
# Found (Custom Doc ID: AP890420-0175)
# Found (Custom Doc ID: AP890501-0078)
# Found (Custom Doc ID: AP890524-0063)
# Found (Custom Doc ID: AP891213-0103)
# Found (Custom Doc ID: AP900214-0142)
# Found (Custom Doc ID: AP900423-0027)
# Found (Custom Doc ID: AP900613-0053)
# Found (Custom Doc ID: AP900810-0162)
# Found (Custom Doc ID: AP890424-0121)
# Found (Custom Doc ID: AP890720-0024)
# Found (Custom Doc ID: AP890720-0178)
# Found (Custom Doc ID: AP890724-0057)
# Found (Custom Doc ID: AP891022-0082)
# Found (Custom Doc ID: AP900212-0190)
# Found (Custom Doc ID: AP900424-0079)
# Found (Custom Doc ID: AP900521-0093)
# Found (Custom Doc ID: AP900607-0153)
# Found (Custom Doc ID: AP900615-0145)
# Found (Custom Doc ID: AP900625-0138)
# Found (Custom Doc ID: AP900704-0106)
# Found (Custom Doc ID: AP900721-0081)
# Found (Custom Doc ID: AP900913-0060)
# Found (Custom Doc ID: AP901003-0149)
# Found (Custom Doc ID: AP901226-0126)
# Found (Custom Doc ID: AP880509-0073)
# Found (Custom Doc ID: AP890304-0047)
# Found (Custom Doc ID: AP890107-0151)
# Found (Custom Doc ID: AP881206-0251)
# Found (Custom Doc ID: AP891215-0173)
# Found (Custom Doc ID: AP901204-0139)
# Found (Custom Doc ID: AP890720-0181)
# Found (Custom Doc ID: AP890721-0055)
# Found (Custom Doc ID: AP880218-0108)
# Found (Custom Doc ID: AP880218-0168)
# Found (Custom Doc ID: AP880328-0166)
# Found (Custom Doc ID: AP880427-0084)
# Found (Custom Doc ID: AP880624-0313)
# Found (Custom Doc ID: AP900614-0192)
# Found (Custom Doc ID: AP891024-0166)
# Found (Custom Doc ID: AP900417-0149)
# Found (Custom Doc ID: AP880212-0027)
# Found (Custom Doc ID: AP880506-0117)
# Found (Custom Doc ID: AP880831-0097)
# Found (Custom Doc ID: AP890907-0114)
# Found (Custom Doc ID: AP880928-0199)
# Found (Custom Doc ID: AP890622-0317)
# Found (Custom Doc ID: AP890103-0248)
# Found (Custom Doc ID: AP891030-0130)
# Found (Custom Doc ID: AP891107-0181)
# Found (Custom Doc ID: AP881126-0115)
# Found (Custom Doc ID: AP881215-0311)
# Found (Custom Doc ID: AP880629-0175)
# Found (Custom Doc ID: AP880704-0114)
# Found (Custom Doc ID: AP890426-0151)
# Found (Custom Doc ID: AP890525-0286)
# Found (Custom Doc ID: AP891120-0143)
# Found (Custom Doc ID: AP900428-0068)
# Found (Custom Doc ID: AP900510-0059)
# Found (Custom Doc ID: AP900618-0136)
# Found (Custom Doc ID: AP900729-0068)
# Found (Custom Doc ID: AP901220-0137)
# Found (Custom Doc ID: AP880216-0184)
# Found (Custom Doc ID: AP880223-0222)
# Found (Custom Doc ID: AP880404-0136)
# Found (Custom Doc ID: AP880404-0145)
# Found (Custom Doc ID: AP880810-0064)
# Found (Custom Doc ID: AP880830-0027)
# Found (Custom Doc ID: AP890804-0141)
# Found (Custom Doc ID: AP890907-0058)
# Found (Custom Doc ID: AP890220-0034)
# Found (Custom Doc ID: AP890227-0174)
# Found (Custom Doc ID: AP890118-0023)
# Found (Custom Doc ID: AP891012-0234)
# Found (Custom Doc ID: AP891102-0280)
# Found (Custom Doc ID: AP880622-0083)
# Found (Custom Doc ID: AP900727-0047)
# Found (Custom Doc ID: AP901101-0101)
# Found (Custom Doc ID: AP880217-0228)
# Found (Custom Doc ID: AP880308-0112)
# Found (Custom Doc ID: AP880817-0118)
# Found (Custom Doc ID: AP890823-0047)
# Found (Custom Doc ID: AP890224-0223)
# Found (Custom Doc ID: AP890303-0004)
# Found (Custom Doc ID: AP880930-0235)
# Found (Custom Doc ID: AP890127-0036)
# Found (Custom Doc ID: AP891212-0064)
# Found (Custom Doc ID: AP891212-0107)
# Found (Custom Doc ID: AP901004-0008)
# Found (Custom Doc ID: AP901007-0030)
# Found (Custom Doc ID: AP880215-0204)
# Found (Custom Doc ID: AP890824-0262)
# Found (Custom Doc ID: AP891017-0110)
# Found (Custom Doc ID: AP881109-0116)
# Found (Custom Doc ID: AP880705-0300)
# Found (Custom Doc ID: AP900111-0214)
# Found (Custom Doc ID: AP900723-0183)
# Found (Custom Doc ID: AP880220-0123)
# Found (Custom Doc ID: AP880411-0088)
# Found (Custom Doc ID: AP880514-0142)
# Found (Custom Doc ID: AP890817-0026)
# Found (Custom Doc ID: AP890817-0178)
# Found (Custom Doc ID: AP890830-0116)
# Found (Custom Doc ID: AP890227-0023)
# Found (Custom Doc ID: AP890630-0260)
# Found (Custom Doc ID: AP881109-0284)
# Found (Custom Doc ID: AP880604-0181)
# Found (Custom Doc ID: AP880609-0278)
# Found (Custom Doc ID: AP880706-0073)
# Found (Custom Doc ID: AP891220-0097)
# Found (Custom Doc ID: AP891220-0179)
# Found (Custom Doc ID: AP900209-0185)
# Found (Custom Doc ID: AP900308-0176)
# Found (Custom Doc ID: AP900416-0127)
# Found (Custom Doc ID: AP900517-0113)
# Found (Custom Doc ID: AP901015-0292)
# Found (Custom Doc ID: AP901023-0079)
# Found (Custom Doc ID: AP901102-0154)
# Found (Custom Doc ID: AP901219-0146)
# Found (Custom Doc ID: AP890419-0093)
# Found (Custom Doc ID: AP900527-0071)
# Found (Custom Doc ID: AP901224-0133)
# Found (Custom Doc ID: AP880215-0017)
# Found (Custom Doc ID: AP880218-0161)
# Found (Custom Doc ID: AP880402-0011)
# Found (Custom Doc ID: AP880426-0155)
# Found (Custom Doc ID: AP880716-0059)
# Found (Custom Doc ID: AP880725-0037)
# Found (Custom Doc ID: AP890803-0196)
# Found (Custom Doc ID: AP890805-0050)
# Found (Custom Doc ID: AP890315-0172)
# Found (Custom Doc ID: AP880909-0173)
# Found (Custom Doc ID: AP890706-0242)
# Found (Custom Doc ID: AP890426-0192)
# Found (Custom Doc ID: AP900303-0021)
# Found (Custom Doc ID: AP900312-0063)
# Found (Custom Doc ID: AP900509-0154)
# Found (Custom Doc ID: AP901102-0029)
# Found (Custom Doc ID: AP901212-0244)
# Found (Custom Doc ID: AP880712-0250)
# Found (Custom Doc ID: AP881004-0223)
# Found (Custom Doc ID: AP900910-0206)
# Found (Custom Doc ID: AP880216-0168)
# Found (Custom Doc ID: AP880229-0288)
# Found (Custom Doc ID: AP880413-0053)
# Found (Custom Doc ID: AP890726-0259)
# Found (Custom Doc ID: AP890831-0023)
# Found (Custom Doc ID: AP890602-0082)
# Found (Custom Doc ID: AP890629-0182)
# Found (Custom Doc ID: AP891016-0047)
# Found (Custom Doc ID: AP891025-0118)
# Found (Custom Doc ID: AP890420-0167)
# Found (Custom Doc ID: AP891208-0191)
# Found (Custom Doc ID: AP891210-0053)
# Found (Custom Doc ID: AP891229-0020)
# Found (Custom Doc ID: AP900124-0020)
# Found (Custom Doc ID: AP900315-0085)
# Found (Custom Doc ID: AP900322-0038)
# Found (Custom Doc ID: AP900511-0189)
# Found (Custom Doc ID: AP900604-0057)
# Found (Custom Doc ID: AP900620-0170)
# Found (Custom Doc ID: AP900723-0098)
# Found (Custom Doc ID: AP901116-0119)
# Found (Custom Doc ID: AP880217-0189)
# Found (Custom Doc ID: AP880219-0002)
# Found (Custom Doc ID: AP880727-0230)
# Found (Custom Doc ID: AP891012-0281)
# Found (Custom Doc ID: AP880629-0006)
# Found (Custom Doc ID: AP900604-0126)
# Found (Custom Doc ID: AP901031-0207)
# Found (Custom Doc ID: AP880608-0046)
# Found (Custom Doc ID: AP901016-0021)
# Found (Custom Doc ID: AP880215-0098)
# Found (Custom Doc ID: AP900531-0202)
# Found (Custom Doc ID: AP880814-0009)
# Found (Custom Doc ID: AP890727-0173)
# Found (Custom Doc ID: AP880712-0206)
# Found (Custom Doc ID: AP890727-0208)
# Found (Custom Doc ID: AP890826-0038)
# Found (Custom Doc ID: AP890719-0094)
# Found (Custom Doc ID: AP881231-0107)
# Found (Custom Doc ID: AP890116-0188)
# Found (Custom Doc ID: AP891011-0170)
# Found (Custom Doc ID: AP891027-0152)
# Found (Custom Doc ID: AP881210-0009)
# Found (Custom Doc ID: AP880607-0130)
# Found (Custom Doc ID: AP880608-0187)
# Found (Custom Doc ID: AP900126-0064)
# Found (Custom Doc ID: AP900309-0137)
# Found (Custom Doc ID: AP900314-0121)
# Found (Custom Doc ID: AP900502-0141)
# Found (Custom Doc ID: AP900820-0028)
# Found (Custom Doc ID: AP880224-0055)
# Found (Custom Doc ID: AP880403-0043)
# Found (Custom Doc ID: AP880520-0090)
# Found (Custom Doc ID: AP890227-0113)
# Found (Custom Doc ID: AP890309-0239)
# Found (Custom Doc ID: AP881001-0062)
# Found (Custom Doc ID: AP890625-0058)
# Found (Custom Doc ID: AP890124-0180)
# Found (Custom Doc ID: AP891007-0113)
# Found (Custom Doc ID: AP881028-0271)
# Found (Custom Doc ID: AP880531-0113)
# Found (Custom Doc ID: AP880607-0132)
# Found (Custom Doc ID: AP880621-0217)
# Found (Custom Doc ID: AP890421-0126)
# Found (Custom Doc ID: AP890428-0168)
# Found (Custom Doc ID: AP890524-0217)
# Found (Custom Doc ID: AP891211-0102)
# Found (Custom Doc ID: AP900111-0129)
# Found (Custom Doc ID: AP900415-0018)
# Found (Custom Doc ID: AP900622-0127)
# Found (Custom Doc ID: AP900903-0033)
# Found (Custom Doc ID: AP901015-0200)
# Found (Custom Doc ID: AP901213-0126)
# Found (Custom Doc ID: AP901214-0064)
# Found (Custom Doc ID: AP880404-0239)
# Found (Custom Doc ID: AP880511-0033)
# Found (Custom Doc ID: AP880819-0179)
# Found (Custom Doc ID: AP890322-0280)
# Found (Custom Doc ID: AP890630-0098)
# Found (Custom Doc ID: AP881110-0265)
# Found (Custom Doc ID: AP900619-0097)
# Found (Custom Doc ID: AP901016-0056)
# Found (Custom Doc ID: AP880214-0094)
# Found (Custom Doc ID: AP880720-0061)
# Found (Custom Doc ID: AP880812-0186)
# Found (Custom Doc ID: AP880818-0152)
# Found (Custom Doc ID: AP880819-0183)
# Found (Custom Doc ID: AP890811-0184)
# Found (Custom Doc ID: AP890216-0106)
# Found (Custom Doc ID: AP890308-0190)
# Found (Custom Doc ID: AP890720-0207)
# Found (Custom Doc ID: AP890114-0149)
# Found (Custom Doc ID: AP891003-0016)
# Found (Custom Doc ID: AP891010-0078)
# Found (Custom Doc ID: AP891026-0227)
# Found (Custom Doc ID: AP881031-0098)
# Found (Custom Doc ID: AP881205-0013)
# Found (Custom Doc ID: AP880624-0292)
# Found (Custom Doc ID: AP890420-0142)
# Found (Custom Doc ID: AP900308-0044)
# Found (Custom Doc ID: AP900524-0054)
# Found (Custom Doc ID: AP901001-0228)
# Found (Custom Doc ID: AP901220-0184)
# Found (Custom Doc ID: AP880214-0060)
# Found (Custom Doc ID: AP880215-0181)
# Found (Custom Doc ID: AP880217-0005)
# Found (Custom Doc ID: AP880217-0040)
# Found (Custom Doc ID: AP880217-0093)
# Found (Custom Doc ID: AP880217-0122)
# Found (Custom Doc ID: AP880316-0066)
# Found (Custom Doc ID: AP880428-0085)
# Found (Custom Doc ID: AP880518-0335)
# Found (Custom Doc ID: AP880715-0016)
# Found (Custom Doc ID: AP880720-0123)
# Found (Custom Doc ID: AP880727-0157)
# Found (Custom Doc ID: AP880802-0074)
# Found (Custom Doc ID: AP890303-0125)
# Found (Custom Doc ID: AP880903-0040)
# Found (Custom Doc ID: AP880909-0049)
# Found (Custom Doc ID: AP880922-0162)
# Found (Custom Doc ID: AP880928-0300)
# Found (Custom Doc ID: AP890606-0189)
# Found (Custom Doc ID: AP890630-0096)
# Found (Custom Doc ID: AP890712-0202)
# Found (Custom Doc ID: AP890725-0128)
# Found (Custom Doc ID: AP890101-0034)
# Found (Custom Doc ID: AP891012-0027)
# Found (Custom Doc ID: AP891013-0166)
# Found (Custom Doc ID: AP891016-0127)
# Found (Custom Doc ID: AP891020-0024)
# Found (Custom Doc ID: AP891022-0094)
# Found (Custom Doc ID: AP891022-0096)
# Found (Custom Doc ID: AP891028-0039)
# Found (Custom Doc ID: AP891031-0194)
# Found (Custom Doc ID: AP881029-0134)
# Found (Custom Doc ID: AP880523-0054)
# Found (Custom Doc ID: AP890419-0202)
# Found (Custom Doc ID: AP890421-0089)
# Found (Custom Doc ID: AP890422-0109)
# Found (Custom Doc ID: AP890516-0150)
# Found (Custom Doc ID: AP891222-0188)
# Found (Custom Doc ID: AP891228-0122)
# Found (Custom Doc ID: AP891230-0104)
# Found (Custom Doc ID: AP900202-0167)
# Found (Custom Doc ID: AP900308-0233)
# Found (Custom Doc ID: AP900411-0176)
# Found (Custom Doc ID: AP900425-0052)
# Found (Custom Doc ID: AP900604-0241)
# Found (Custom Doc ID: AP900606-0048)
# Found (Custom Doc ID: AP900606-0192)
# Found (Custom Doc ID: AP900801-0028)
# Found (Custom Doc ID: AP901108-0104)
# Found (Custom Doc ID: AP880219-0032)
# Found (Custom Doc ID: AP880309-0036)
# Found (Custom Doc ID: AP880720-0171)
# Found (Custom Doc ID: AP890909-0044)
# Found (Custom Doc ID: AP890303-0126)
# Found (Custom Doc ID: AP890327-0063)
# Found (Custom Doc ID: AP881019-0106)
# Found (Custom Doc ID: AP890125-0281)
# Found (Custom Doc ID: AP890204-0054)
# Found (Custom Doc ID: AP891006-0225)
# Found (Custom Doc ID: AP880621-0339)
# Found (Custom Doc ID: AP880625-0201)
# Found (Custom Doc ID: AP880627-0033)
# Found (Custom Doc ID: AP880630-0107)
# Found (Custom Doc ID: AP880630-0123)
# Found (Custom Doc ID: AP880709-0059)
# Found (Custom Doc ID: AP900126-0203)
# Found (Custom Doc ID: AP900526-0049)
# Found (Custom Doc ID: AP900605-0118)
# Found (Custom Doc ID: AP901108-0090)
# Found (Custom Doc ID: AP901214-0066)
# Found (Custom Doc ID: AP880213-0155)
# Found (Custom Doc ID: AP880223-0018)
# Found (Custom Doc ID: AP880223-0116)
# Found (Custom Doc ID: AP890613-0177)
# Found (Custom Doc ID: AP890204-0001)
# Found (Custom Doc ID: AP881108-0084)
# Found (Custom Doc ID: AP891115-0098)
# Found (Custom Doc ID: AP891221-0164)
# Found (Custom Doc ID: AP900630-0061)
# Found (Custom Doc ID: AP880416-0030)
# Found (Custom Doc ID: AP880501-0046)
# Found (Custom Doc ID: AP890906-0147)
# Found (Custom Doc ID: AP890309-0186)
# Found (Custom Doc ID: AP881004-0006)
# Found (Custom Doc ID: AP890629-0277)
# Found (Custom Doc ID: AP890630-0256)
# Found (Custom Doc ID: AP890724-0065)
# Found (Custom Doc ID: AP891106-0022)
# Found (Custom Doc ID: AP880609-0126)
# Found (Custom Doc ID: AP891113-0064)
# Found (Custom Doc ID: AP900227-0265)
# Found (Custom Doc ID: AP900525-0262)
# Found (Custom Doc ID: AP900626-0101)
# Found (Custom Doc ID: AP901002-0026)
# Found (Custom Doc ID: AP901106-0073)
# Found (Custom Doc ID: AP880217-0101)
# Found (Custom Doc ID: AP880217-0115)
# Found (Custom Doc ID: AP880224-0111)
# Found (Custom Doc ID: AP880229-0151)
# Found (Custom Doc ID: AP880301-0022)
# Found (Custom Doc ID: AP880309-0117)
# Found (Custom Doc ID: AP880421-0202)
# Found (Custom Doc ID: AP880803-0063)
# Found (Custom Doc ID: AP890805-0142)
# Found (Custom Doc ID: AP890809-0018)
# Found (Custom Doc ID: AP890408-0044)
# Found (Custom Doc ID: AP880928-0244)
# Found (Custom Doc ID: AP890622-0322)
# Found (Custom Doc ID: AP891014-0126)
# Found (Custom Doc ID: AP890529-0139)
# Found (Custom Doc ID: AP891212-0053)
# Found (Custom Doc ID: AP901031-0029)
# Found (Custom Doc ID: AP880225-0261)
# Found (Custom Doc ID: AP880429-0136)
# Found (Custom Doc ID: AP880818-0047)
# Found (Custom Doc ID: AP880819-0016)
# Found (Custom Doc ID: AP880902-0176)
# Found (Custom Doc ID: AP880921-0157)
# Found (Custom Doc ID: AP890720-0190)
# Found (Custom Doc ID: AP880623-0174)
# Found (Custom Doc ID: AP900104-0009)
# Found (Custom Doc ID: AP900606-0038)
# Found (Custom Doc ID: AP900902-0053)
# Found (Custom Doc ID: AP901115-0121)
# Found (Custom Doc ID: AP880213-0163)

# %%
reader.close()

# %% [markdown]
# ### Evaluation

# %%
import glob
import gzip
import re

topic_pattern = re.compile(r'<top>(.*?)</top>', re.DOTALL)
# Regular expressions for individual elements
num_pattern = re.compile(r'<num>\s*Number:\s*(\d+)')
title_pattern = re.compile(r'<title>\s*Topic:\s*(.*?)\s*\n')
desc_pattern = re.compile(r'<desc>\s*Description:\s*(.*?)\s*<narr>', re.DOTALL)

def get_requests() :
    requests = []
    
    # Get a list of all topics files in the "Topics-requetes" directory
    file_list = [
       "TREC AP 88-90/TREC AP 88-90/Topics-requetes/topics.1-50.txt",
       "TREC AP 88-90/TREC AP 88-90/Topics-requetes/topics.51-100.txt",
       "TREC AP 88-90/TREC AP 88-90/Topics-requetes/topics.101-150.txt",
    ]
    # Loop over the list of files
    for filename in file_list:

        # Open the .gz file
        with open(filename, 'r') as file:
            # Read the content of the file
            topic_requests_string = file.read()
            for topic in topic_pattern.finditer(topic_requests_string):
                topic_content = topic.group(1)

                # Extracting individual elements
                topic_id = num_pattern.search(topic_content)
                title = title_pattern.search(topic_content)
                desc = desc_pattern.search(topic_content)
                
                if(topic_id) :
                    requests.append([topic_id.group(1), title.group(1) if title else None, desc.group(1).strip() if desc else None])
                    
    return requests 

def build_request(requests) :
    short_requests = []
    long_requests = []
    for request in requests :  
        # request[1] => title , request[2] => description
        short_requests.append(request[1])
        long_requests.append(request[1] + request[2])
    return (short_requests, long_requests)

from java.io import File
from org.apache.lucene.analysis.standard import StandardAnalyzer
from org.apache.lucene.search import IndexSearcher
from org.apache.lucene.search.similarities import ClassicSimilarity, BM25Similarity, LMJelinekMercerSimilarity, BooleanSimilarity
from org.apache.lucene.index import  DirectoryReader
from org.apache.lucene.store import FSDirectory
from org.apache.lucene.queryparser.classic import QueryParser

def set_similirity_weight_schemat(searcher, weight_schemat) :
    if weight_schemat == "classic" : 
        searcher.setSimilarity(ClassicSimilarity())
    if weight_schemat == "bm25" : 
        searcher.setSimilarity(BM25Similarity(1.2,0.75))
    if weight_schemat == "LM" : 
        searcher.setSimilarity(LMJelinekMercerSimilarity(0.7))
    if weight_schemat == "boolean" : 
        searcher.setSimilarity(BooleanSimilarity())

def get_requests_run(queries) :
    run = []
    for index, query_string in enumerate(queries) :
        # Check if the query string is empty or consists of only whitespace
        try :
            query_string = query_string.replace("/", "").replace("?", "").replace("`", "").replace("(", "").replace(")", "")
            query = QueryParser("content", analyzer).parse(query_string)
            hits = searcher.search(query, 1000).scoreDocs

            # Check if the query has any hits
            if len(hits) == 0 :
                print("No hits found for query : ", query_string)
           
            for i,hit in enumerate(hits):
                doc = searcher.doc(hit.doc)
                run.append((index+1, "Q0", doc.get("doc_id"), i+1, hit.score, "trec_run"))
        except :
            print("Error in query : ", query_string)
            continue
    return run

def write_run_file(results, file_path):
    with open(file_path, 'w') as f:
        for result in results:
            f.write(" ".join(map(str, result)) + "\n")

# %%
similarity = "LM"

queries = get_requests() 
reader = DirectoryReader.open(index)
searcher = IndexSearcher(reader)
set_similirity_weight_schemat(searcher, similarity)

# build_request 
short_requests, long_requests = build_request(queries)

short_requests_run = get_requests_run(short_requests)
long_requests_run = get_requests_run(long_requests)

print(short_requests_run[0])
print(long_requests_run[0])
write_run_file(short_requests_run, "TREC AP 88-90/TREC AP 88-90/trec_runs/short_basic_" + similarity + ".run")
write_run_file(long_requests_run, "TREC AP 88-90/TREC AP 88-90/trec_runs/long_basic_" + similarity + ".run")
# Out:
# (1, 'Q0', 'AP890731-0265', 1, 11.58420181274414, 'trec_run')
# (1, 'Q0', 'AP890731-0265', 1, 19.042831420898438, 'trec_run')

# %% [markdown]
# ### Trec eval

# %%
from trectools import TrecEval, TrecQrel, TrecRun

def trec_eval(run_path, qrel_path):
    run = TrecRun(run_path)
    qrel= TrecQrel(qrel_path)
    te = TrecEval(run, qrel)

    result = {}
    result["num_ret"] = te.get_retrieved_documents(per_query=False)
    result["num_rel"] = te.get_relevant_documents(per_query=False)
    result["num_rel_ret"] = te.get_relevant_retrieved_documents(per_query=False)
    result["map"] = te.get_map(depth=1000, per_query=False, trec_eval=True) 
    for v in [5, 10, 15, 20, 30, 100, 200, 500, 1000]:
        result[f"P@{v}"] = te.get_precision(depth=v, per_query=False, trec_eval=True)

    return result

def format_res(overall_result) :
  map_values = [inner_dict['map'] for inner_dict in overall_result.values()]
  mean_map = sum(map_values) / len(map_values)
  P_10 = [inner_dict['P@10'] for inner_dict in overall_result.values()]
  mean_P_10 = sum(P_10) / len(P_10)
  # 5, 10, 15, 20, 30, 100, 200, 500, 1000
  return { 
    "MMAP" : mean_map, 
    "P@10" :mean_P_10,
    "num_ret": overall_result["1"]["num_ret"], 
    "num_rel": overall_result["1"]["num_rel"],
    "num_rel_ret" : overall_result["1"]["num_rel_ret"],
  }

# %% [markdown]
# ### STEMME

# %%
long_stemme_bm25 = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_stemme_bm25.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_stemme_bm25)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 12365, 'map': 0.1906649454549337, 'P@5': 0.3946666666666667, 'P@10': 0.37666666666666665, 'P@15': 0.3595555555555556, 'P@20': 0.344, 'P@30': 0.3222222222222222, 'P@100': 0.2474, 'P@200': 0.19613333333333335, 'P@500': 0.12604, 'P@1000': 0.08243333333333334}

# %%
long_stemme_classic = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_stemme_classic.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_stemme_classic)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 11053, 'map': 0.14909556560447088, 'P@5': 0.2946666666666667, 'P@10': 0.2873333333333333, 'P@15': 0.2782222222222222, 'P@20': 0.2676666666666667, 'P@30': 0.2597777777777778, 'P@100': 0.20713333333333334, 'P@200': 0.1663, 'P@500': 0.10836000000000001, 'P@1000': 0.07368666666666666}

# %%
long_stemme_lm = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_stemme_LM.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_stemme_lm)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 11610, 'map': 0.17500922752299103, 'P@5': 0.376, 'P@10': 0.32666666666666666, 'P@15': 0.31155555555555553, 'P@20': 0.3053333333333333, 'P@30': 0.29111111111111115, 'P@100': 0.22753333333333334, 'P@200': 0.1801, 'P@500': 0.11737333333333334, 'P@1000': 0.07739333333333334}

# %%
short_stemme_bm25 = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_stemme_bm25.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_stemme_bm25)
# Out:
# {'num_ret': 144288, 'num_rel': 25549, 'num_rel_ret': 11488, 'map': 0.18136221076223133, 'P@5': 0.35333333333333333, 'P@10': 0.33066666666666666, 'P@15': 0.3146666666666667, 'P@20': 0.30466666666666664, 'P@30': 0.2902222222222222, 'P@100': 0.2305333333333333, 'P@200': 0.18513333333333334, 'P@500': 0.11834666666666666, 'P@1000': 0.07658}

# %%
short_stemme_classic = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_stemme_classic.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_stemme_classic)
# Out:
# {'num_ret': 144288, 'num_rel': 25549, 'num_rel_ret': 10397, 'map': 0.13537729488258624, 'P@5': 0.24666666666666667, 'P@10': 0.24400000000000002, 'P@15': 0.24177777777777776, 'P@20': 0.23433333333333337, 'P@30': 0.23155555555555557, 'P@100': 0.1864, 'P@200': 0.1539666666666667, 'P@500': 0.10250666666666668, 'P@1000': 0.06931333333333334}

# %%
short_stemme_lm = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_stemme_LM.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_stemme_lm)
# Out:
# {'num_ret': 144288, 'num_rel': 25549, 'num_rel_ret': 10977, 'map': 0.16457703092183423, 'P@5': 0.32533333333333336, 'P@10': 0.29533333333333334, 'P@15': 0.28444444444444444, 'P@20': 0.27599999999999997, 'P@30': 0.2602222222222222, 'P@100': 0.21153333333333335, 'P@200': 0.173, 'P@500': 0.11132, 'P@1000': 0.07318000000000001}

# %% [markdown]
# ### BASIC

# %%
long_basic_bm25 = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_basic_bm25.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_basic_bm25)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 11019, 'map': 0.1668214469130914, 'P@5': 0.38666666666666666, 'P@10': 0.3513333333333334, 'P@15': 0.3342222222222222, 'P@20': 0.3203333333333333, 'P@30': 0.2988888888888889, 'P@100': 0.22446666666666668, 'P@200': 0.17503333333333332, 'P@500': 0.11262666666666665, 'P@1000': 0.07346000000000001}

# %%
long_basic_classic = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_basic_classic.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_basic_classic)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 9726, 'map': 0.12732352486635037, 'P@5': 0.27199999999999996, 'P@10': 0.26733333333333337, 'P@15': 0.26666666666666666, 'P@20': 0.25600000000000006, 'P@30': 0.24, 'P@100': 0.18420000000000003, 'P@200': 0.14673333333333333, 'P@500': 0.09694666666666668, 'P@1000': 0.06484}

# %%
long_basic_LM = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/long_basic_LM.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(long_basic_LM)
# Out:
# {'num_ret': 150000, 'num_rel': 25549, 'num_rel_ret': 10385, 'map': 0.14989938727803764, 'P@5': 0.3466666666666667, 'P@10': 0.31533333333333335, 'P@15': 0.3008888888888888, 'P@20': 0.28433333333333327, 'P@30': 0.26844444444444443, 'P@100': 0.205, 'P@200': 0.15983333333333336, 'P@500': 0.10476000000000002, 'P@1000': 0.06923333333333333}

# %%
short_basic_bm25 = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_basic_bm25.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_basic_bm25)
# Out:
# {'num_ret': 143631, 'num_rel': 25549, 'num_rel_ret': 10062, 'map': 0.15695876880382706, 'P@5': 0.33866666666666667, 'P@10': 0.31333333333333335, 'P@15': 0.29777777777777775, 'P@20': 0.285, 'P@30': 0.27, 'P@100': 0.20693333333333333, 'P@200': 0.16133333333333333, 'P@500': 0.10196000000000001, 'P@1000': 0.06708000000000001}

# %%
short_basic_classic = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_basic_classic.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_basic_classic)
# Out:
# {'num_ret': 143631, 'num_rel': 25549, 'num_rel_ret': 9045, 'map': 0.1130943997839862, 'P@5': 0.20800000000000002, 'P@10': 0.21733333333333335, 'P@15': 0.21244444444444444, 'P@20': 0.21333333333333335, 'P@30': 0.212, 'P@100': 0.16706666666666667, 'P@200': 0.13453333333333334, 'P@500': 0.08845333333333334, 'P@1000': 0.06029333333333334}

# %%
short_basic_LM = trec_eval("TREC AP 88-90/TREC AP 88-90/trec_runs/short_basic_LM.run", "TREC AP 88-90/TREC AP 88-90/jugements de pertinence/qrels.1-150-AP8890.txt")
print(short_basic_LM)
# Out:
# {'num_ret': 143631, 'num_rel': 25549, 'num_rel_ret': 9435, 'map': 0.13894211367637874, 'P@5': 0.30533333333333335, 'P@10': 0.28, 'P@15': 0.26844444444444443, 'P@20': 0.25933333333333325, 'P@30': 0.2451111111111111, 'P@100': 0.19173333333333334, 'P@200': 0.15093333333333334, 'P@500': 0.09462666666666666, 'P@1000': 0.06289333333333333}
